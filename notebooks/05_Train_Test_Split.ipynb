# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/processed/final_processed_data.csv")

# %%
df.shape
# Out:
# (307511, 215)

# %%
df.drop("SK_ID_CURR", axis=1, inplace=True)

# %%
df.shape
# Out:
# (307511, 214)

# %%
X = df.drop("TARGET", axis=1)

y = df["TARGET"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (307511, 213)
# (307511,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=42,stratify=y)

# %%
print("Training Features :", X_train.shape)
print("Testing Features  :", X_test.shape)

print("Training Target   :", y_train.shape)
print("Testing Target    :", y_test.shape)
# Out:
# Training Features : (246008, 213)
# Testing Features  : (61503, 213)
# Training Target   : (246008,)
# Testing Target    : (61503,)

# %%
print(y_train.value_counts(normalize=True))
# Out:
# TARGET
# 0    0.919271
# 1    0.080729
# Name: proportion, dtype: float64

# %%
print(y_test.value_counts(normalize=True))
# Out:
# TARGET
# 0    0.919272
# 1    0.080728
# Name: proportion, dtype: float64

# %%
X_train.to_csv("../data/train/X_train.csv", index=False)

X_test.to_csv("../data/test/X_test.csv", index=False)

y_train.to_csv("../data/train/y_train.csv", index=False)

y_test.to_csv("../data/test/y_test.csv", index=False)
