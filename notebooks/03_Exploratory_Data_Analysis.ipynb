# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed/cleaned_application_train.csv")

# %%
df["TARGET"].value_counts()
# Out:
# TARGET
# 0    282686
# 1     24825
# Name: count, dtype: int64

# %%
sns.countplot(x="TARGET", data=df)
plt.title("Target Variable Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["AMT_INCOME_TOTAL"], bins=30, kde=True)
plt.title("Income Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["AMT_CREDIT"], bins=30, kde=True)
plt.title("Income Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["AMT_ANNUITY"], bins=30, kde=True)
plt.title("Income Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["DAYS_BIRTH"], bins=30, kde=True)
plt.title("Income Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["DAYS_EMPLOYED"], bins=30, kde=True)
plt.title("Income Distribution")
plt.show()

# %%
sns.boxplot(x=df["AMT_INCOME_TOTAL"])
plt.title("Income Boxplot")
plt.show()

# %%
sns.boxplot(x=df["AMT_CREDIT"])
plt.title("credit Amount Boxplot")
plt.show()

# %%
sns.boxplot(x=df["AMT_ANNUITY"])
plt.title("annuity Amount Boxplot")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(y="NAME_EDUCATION_TYPE", data=df)
plt.title("Education Level")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(y="NAME_CONTRACT_TYPE", data=df)
plt.title("contract type")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(y="CODE_GENDER", data=df)
plt.title("code gender")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(y="NAME_INCOME_TYPE", data=df)
plt.title("INCOME TYPE")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(y="NAME_FAMILY_STATUS", data=df)
plt.title("NAME_FAMILY_STATUS")
plt.show()

# %%
sns.countplot(x="CODE_GENDER", hue="TARGET", data=df)
plt.title("Loan Default by Gender")
plt.show()

# %%
sns.countplot(x="NAME_EDUCATION_TYPE", hue="TARGET", data=df)
plt.title("Loan Default NAME_EDUCATION_TYPE")
plt.tight_layout()
plt.show()

# %%
sns.countplot(x="NAME_INCOME_TYPE", hue="TARGET", data=df)
plt.title("Loan Default NAME_INCOME_TYPE")
plt.show()

# %%
sns.countplot(x="NAME_FAMILY_STATUS", hue="TARGET", data=df)
plt.title("Loan Default by NAME_FAMILY_STATUS")
plt.show()

# %%
sns.countplot(x="NAME_CONTRACT_TYPE", hue="TARGET", data=df)
plt.title("Loan Default by NAME_CONTRACT_TYPE")
plt.show()

# %%
numeric_df = df.select_dtypes(include=["int64","float64"])

# %%
corr = numeric_df.corr()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(corr, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
corr["TARGET"].sort_values(ascending=False)
# Out:
# TARGET                         1.000000
# DAYS_BIRTH                     0.078239
# REGION_RATING_CLIENT_W_CITY    0.060893
# REGION_RATING_CLIENT           0.058899
# DAYS_LAST_PHONE_CHANGE         0.055218
#                                  ...
# FLOORSMAX_AVG                 -0.044003
# DAYS_EMPLOYED                 -0.044932
# EXT_SOURCE_1                  -0.155317
# EXT_SOURCE_2                  -0.160472
# EXT_SOURCE_3                  -0.178919
# Name: TARGET, Length: 106, dtype: float64

# %%
missing = (df.isnull().sum()/len(df))*100
missing = missing[missing>0]

missing.sort_values(ascending=False).head(20).plot(kind="bar", figsize=(12,5))
plt.title("Top 20 Columns with Missing Values")
plt.show()

# %%
plt.savefig("../images/target_distribution.png")
plt.savefig("../images/income_distribution.png")
plt.savefig("../images/credit_distribution.png")
plt.savefig("../images/age_distribution.png")
plt.savefig("../images/ correlation_heatmap.png")
